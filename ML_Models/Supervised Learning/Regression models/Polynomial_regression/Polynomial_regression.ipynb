# %% [markdown]
# # **Polynomial Regression Model Theory**

# %% [markdown]
# ## Theory: Polynomial Regression
#
# Polynomial regression is an extension of linear regression where the model considers higher-degree polynomial features of the input data. This allows it to model more complex relationships between the input variables and the output.
#
# The model function for polynomial regression of degree \( n \) is represented as:
#
# $$ f_{w,b}(x) = w_0 + w_1 x + w_2 x^2 + \cdots + w_n x^n + b $$
#
# Where:
# - \( f_{w,b}(x) \) is the predicted output.
# - \( w_0, w_1, \dots, w_n \) are the weight parameters.
# - \( b \) is the bias parameter.
# - \( x \) is the input feature.
# - \( n \) is the degree of the polynomial.
#
# ## Model Training
#
# To train a polynomial regression model, we aim to find the best values for the parameters \( (w_0, w_1, \dots, w_n, b) \) that best fit our dataset. The process is similar to linear regression, but we include higher powers of the input \( x \) as features.
#
# ### Forward Pass
#
# The forward pass is where we compute the polynomial regression output for the input data \( X \) using the current weights and biases. The equation becomes:
#
# $$ f_{w,b}(X) = w_0 + w_1 X + w_2 X^2 + \cdots + w_n X^n + b $$
#
# ### Cost Function
#
# The cost function for polynomial regression is the same as for linear regression. It quantifies how well the model's predictions match the actual outputs. The cost function is defined as:
#
# $$ J(w, b) = \frac{1}{2m} \sum_{i=1}^{m} \left( f_{w,b}(x^{(i)}) - y^{(i)} \right)^2 $$
#
# Where:
# - \( J(w, b) \) is the cost.
# - \( m \) is the number of training examples.
# - \( x^{(i)} \) is the input data for the \( i \)-th example.
# - \( y^{(i)} \) is the actual output for the \( i \)-th example.
# - \( w \) and \( b \) are the weight and bias parameters.
#
# ### Backward Pass (Gradient Computation)
#
# The backward pass computes the gradients of the cost function with respect to the parameters. The gradients represent how much the cost function changes with respect to each parameter. These gradients are needed for updating the parameters during training.
#
# The gradients for the weights and bias are as follows:
#
# $$ \frac{\partial J(w,b)}{\partial b} = \frac{1}{m} \sum_{i=0}^{m-1} \left( f_{w,b}(x^{(i)}) - y^{(i)} \right) $$
#
# $$ \frac{\partial J(w,b)}{\partial w_k} = \frac{1}{m} \sum_{i=0}^{m-1} \left( f_{w,b}(x^{(i)}) - y^{(i)} \right) \cdot x^{(i)k}, \quad \text{for } k = 1, 2, \dots, n $$
#
# Where \( x^{(i)k} \) represents the \( k \)-th power of the input feature \( x^{(i)} \).
#
# ### Training Process
#
# The training process involves iteratively updating the weights and biases to minimize the cost function, typically using gradient descent or other optimization algorithms.
#
# The update equations for the parameters are:
#
# $$ w_k \leftarrow w_k - \alpha \frac{\partial J}{\partial w_k}, \quad \text{for } k = 0, 1, \dots, n $$
#
# $$ b \leftarrow b - \alpha \frac{\partial J}{\partial b} $$
#
# Where:
# - \( \alpha \) is the learning rate, controlling the step size during updates.
#
# By performing the forward pass, computing the cost, performing the backward pass, and updating the parameters, the polynomial regression model iteratively learns to fit the data.

# %% [markdown]
# ## **Model Evaluation**
#
# ### 1. Mean Squared Error (MSE)
#
# **Formula:**
# $$
# \text{MSE} = \frac{1}{n} \sum_{i=1}^{n} (y_{\text{true}_i} - y_{\text{pred}_i})^2
# $$
#
# **Description:**
# - **Mean Squared Error (MSE)** is a widely used metric for evaluating the accuracy of regression models.
# - It measures the average squared difference between the predicted values ($y_{\text{pred}}$) and the actual target values ($y_{\text{true}}$).
# - The squared differences are averaged across all data points in the dataset.
#
# **Interpretation:**
# - A lower MSE indicates a better fit of the model to the data, as it means the model's predictions are closer to the actual values.
# - MSE is sensitive to outliers because the squared differences magnify the impact of large errors.
# - **Limitations:**
#   - MSE can be hard to interpret because it is in squared units of the target variable.
#   - It disproportionately penalizes larger errors due to the squaring process.
#
# ---
#
# ### 2. Root Mean Squared Error (RMSE)
#
# **Formula:**
# $$
# \text{RMSE} = \sqrt{\text{MSE}}
# $$
#
# **Description:**
# - **Root Mean Squared Error (RMSE)** is a variant of MSE that provides the square root of the average squared difference between predicted and actual values.
# - It is often preferred because it is in the same unit as the target variable, making it more interpretable.
#
# **Interpretation:**
# - Like MSE, a lower RMSE indicates a better fit of the model to the data.
# - RMSE is also sensitive to outliers due to the square root operation.
# - **Advantages over MSE:**
#   - RMSE provides a more intuitive interpretation since it is in the same scale as the target variable.
#   - It can be more directly compared to the values of the actual data.
#
# ---
#
# ### 3. R-squared ($R^2$)
#
# **Formula:**
# $$
# R^2 = 1 - \frac{\text{SSR}}{\text{SST}}
# $$
#
# **Description:**
# - **R-squared ($R^2$)**, also known as the coefficient of determination, measures the proportion of the variance in the dependent variable ($y_{\text{true}}$) that is predictable from the independent variable(s) ($y_{\text{pred}}$) in a regression model.
# - It ranges from 0 to 1, where 0 indicates that the model does not explain any variance, and 1 indicates a perfect fit.
#
# **Interpretation:**
# - A higher $R^2$ value suggests that the model explains a larger proportion of the variance in the target variable.
# - However, $R^2$ does not provide information about the goodness of individual predictions or whether the model is overfitting or underfitting.
# - **Limitations:**
#   - $R^2$ can be misleading in cases of overfitting, especially with polynomial regression models. Even if $R^2$ is high, the model may not generalize well to unseen data.
#   - It doesn’t penalize for adding irrelevant predictors, so adjusted $R^2$ is often preferred for models with multiple predictors.
#
# ---
#
# ### 4. Adjusted R-squared
#
# **Formula:**
# $$
# \text{Adjusted } R^2 = 1 - \left(1 - R^2\right) \frac{n-1}{n-p-1}
# $$
# where \(n\) is the number of data points and \(p\) is the number of predictors.
#
# **Description:**
# - **Adjusted R-squared** adjusts the R-squared value to account for the number of predictors in the model, helping to prevent overfitting when adding more terms to the model.
# - Unlike $R^2$, it can decrease if the additional predictors do not improve the model significantly.
#
# **Interpretation:**
# - A higher adjusted $R^2$ suggests that the model is not just overfitting, but has genuine explanatory power with the number of predictors taken into account.
# - It is especially useful when comparing models with different numbers of predictors.
#
# ---
#
# ### 5. Mean Absolute Error (MAE)
#
# **Formula:**
# $$
# \text{MAE} = \frac{1}{n} \sum_{i=1}^{n} |y_{\text{true}_i} - y_{\text{pred}_i}|
# $$
#
# **Description:**
# - **Mean Absolute Error (MAE)** measures the average of the absolute errors between the predicted and actual values.
# - Unlike MSE and RMSE, MAE is not sensitive to outliers because it does not square the errors.
#
# **Interpretation:**
# - MAE provides a straightforward understanding of the average error magnitude.
# - A lower MAE suggests better model accuracy, but it may not highlight the impact of large errors as much as MSE or RMSE.

# %% [markdown]
# ## sklearn template [sckit-kit: PolynomialFeatures](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html)
#
# ### **class sklearn.preprocessing.PolynomialFeatures(degree=2, *, interaction_only=False, include_bias=True, order='C')**
#
# | **Parameter**      | **Description**                                                                                                  | **Default**     |
# |--------------------|------------------------------------------------------------------------------------------------------------------|-----------------|
# | `degree`           | The degree of the polynomial features.                                                                            | `2`             |
# | `interaction_only` | If True, only interaction features are produced: features that are products of two or more features.             | `False`         |
# | `include_bias`     | If True, includes a bias (intercept) column in the output.                                                       | `True`          |
# | `order`            | Specifies the order of the output features. Available options are `'C'` (row-major) or `'F'` (column-major).      | `'C'`           |
#
# ---
#
# ### **Attributes**
#
# | **Attribute**       | **Description**                                                                                                  |
# |---------------------|------------------------------------------------------------------------------------------------------------------|
# | `n_input_features_` | The number of features in the input data `X` (i.e., before polynomial transformation).                          |
# | `powers_`           | The powers of the features for each polynomial feature.                                                          |
# | `n_features_out_`   | The number of output features after polynomial transformation (which includes interactions and bias if applicable).|
#
# ---
#
# ### **Methods**
#
# | **Method**                        | **Description**                                                                                                    |
# |-----------------------------------|--------------------------------------------------------------------------------------------------------------------|
# | `fit(X, y=None)`                  | Computes the number of output features based on the input data `X`.                                               |
# | `fit_transform(X, y=None, **fit_params)` | Fits the transformer to `X` and `y`, then transforms `X` into polynomial features.                                 |
# | `get_feature_names_out(input_features=None)` | Returns output feature names for the transformed data.                                                              |
# | `get_metadata_routing()`         | Retrieves metadata routing information for this object.                                                           |
# | `get_params(deep=True)`          | Gets the parameters for the estimator (including nested subobjects, if `deep=True`).                               |
# | `powers_`                        | Property that returns the exponents for each of the inputs in the output features.                                 |
# | `set_output(*, transform=None)`   | Sets the output container format. Can be `'default'`, `'pandas'`, or `'polars'`.                                   |
# | `set_params(**params)`           | Sets the parameters of the estimator, including nested objects.                                                   |
# | `transform(X)`                   | Transforms the data `X` into polynomial features.                                                                  |
#
# ---

# %% [markdown]
# # Polynomial Regression  - Example

# %% [markdown]
# ## Data loading

# %%
import pandas as pd

# import data
df = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Economy%20of%20Scale.csv')

df.head()
# Out:
#    Units  Cost
# 0    1.0  95.1
# 1    1.2  96.5
# 2    1.2  73.7
# 3    1.2  95.6
# 4    1.3  98.8

# %% [markdown]
# ##  Data processing

# %%
y = df['Cost']
X = df[['Units']]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state =2529)

# %% [markdown]
# ## Plotting data

# %%
import seaborn as sns

sns.pairplot(df)

# %% [markdown]
# ## Model definition

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Initialize PolynomialFeatures for degree 2 polynomial features
poly = PolynomialFeatures(degree=3, interaction_only=False, include_bias=True, order='C')

# Transform training data
X_train_poly = poly.fit_transform(X_train)

# Fit polynomial regression model
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Transform test data and make predictions
X_test_poly = poly.transform(X_test)
y_pred = model.predict(X_test_poly)

# Print the model coefficients and intercept
print(f"Model Coefficients: {model.coef_}")
print(f"Model Intercept: {model.intercept_}")

# Evaluate model performance
predictions = model.predict(X_test_poly)
# Out:
# Model Coefficients: [  0.         -31.14305074   4.44303801  -0.22711399]
# Model Intercept: 108.43184212051534

# %% [markdown]
# ## Model evaulation

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, predictions)

# Calculate Root Mean Squared Error (RMSE)
rmse = mse ** 0.5

# Calculate R² (Coefficient of Determination)
r2 = r2_score(y_test, predictions)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, predictions)

# Calculate Adjusted R²
n = len(y_test)  # number of data points
p = X_test_poly.shape[1]  # number of predictors (after polynomial transformation)
adj_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

# Print evaluation metrics
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
print(f"MAE: {mae}")
print(f"Adjusted R²: {adj_r2}")
# Out:
# MSE: 35.147686458706275
# RMSE: 5.928548427625962
# R²: 0.7430634893542617
# MAE: 4.3593766758910295
# Adjusted R²: 0.7388686075478006

# %%
import matplotlib.pyplot as plt

# Plotting the results
plt.scatter(X, y, color='blue', label='Original data')
X_range = np.linspace(min(X['Units']), max(X['Units']), 100).reshape(-1, 1)
X_range_poly = poly.transform(X_range)
y_range_pred = model.predict(X_range_poly)
plt.plot(X_range, y_range_pred, color='red', label='Polynomial Regression')
plt.title('Polynomial Regression: Economy of Scale')
plt.xlabel('Units')
plt.ylabel('Cost')
plt.legend()
plt.show()
# Out:
# /home/petar-ubuntu/Learning/ML_Theory/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
